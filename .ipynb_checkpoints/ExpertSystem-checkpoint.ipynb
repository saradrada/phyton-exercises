# %% [markdown]
# # Expert Systems

# %% [markdown]
# Daniela Llano Lozano y Sara Ortiz Drada

# %% [markdown]
# ### Entorno

# %%
from pyknow import *

class Ph():
    ALCALINO = "ALCALINO"
    LIGERAMENTE_ALCALINO ="LIGERAMENTE ALCALINO"
    LIGERAMENTE_ACIDO = "LIGERAMENTE ACIDO"
    NEUTRO = "NEUTRO"
    ACIDO = "ACIDO"
    pass

class Ce:
    ALTA="ALTA"
    BAJA="BAJA"
    pass

class Land(Fact):
    pass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d7aacb47e2bf> in <module>
# ----> 1 from pyknow import *
#       2
#       3 class Ph():
#       4     ALCALINO = "ALCALINO"
#       5     LIGERAMENTE_ALCALINO ="LIGERAMENTE ALCALINO"
#
# ModuleNotFoundError: No module named 'pyknow'

# %% [markdown]
# ### Reglas

# %%
class LandRules(KnowledgeEngine):

    @Rule(Land(ph=P(lambda ph: ph >= 7.2)))
    def rule_1(self):
        print("\n\n")
        print("=> ph: %s" %(Ph.ALCALINO))
        self.declare(Land(Ph.ALCALINO))
        
    @Rule(Land(ph=P(lambda ph: ph > 6.8) & P(lambda ph: ph < 7.2)))
    def rule_2(self):
        print("\n\n")
        print("=> ph: %s" %(Ph.LIGERAMENTE_ALCALINO))
        self.declare(Land(Ph.LIGERAMENTE_ALCALINO))

    @Rule(Land(ph=P(lambda ph: ph <= 6.8) & P(lambda ph: ph >= 6.2)))
    def rule_3(self):
        print("\n\n")
        print("=> ph: %s" %(Ph.NEUTRO))
        self.declare(Land(Ph.NEUTRO))

    @Rule(Land(ph=P(lambda ph: ph > 5.6) & P(lambda ph: ph < 6.2)))
    def rule_4(self):
        print("\n\n")
        print("=> ph: %s" %(Ph.LIGERAMENTE_ACIDO))
        self.declare(Land(Ph.LIGERAMENTE_ACIDO))

    @Rule(Land(ph=P(lambda ph: ph <= 5.6)))
    def rule_5(self):
        print("\n\n")
        print("=> ph: %s" %(Ph.ACIDO))
        self.declare(Land(Ph.ACIDO))

    @Rule(Land(ce=P(lambda ce: ce < 0.8)))
    def rule_6(self):
        print("\n\n")
        print("=> ce: %s" %(Ce.BAJA))
        self.declare(Land(Ce.BAJA))

    @Rule(Land(ce=P(lambda ce: ce >= 0.8)))
    def rule_7(self):
        print("\n\n")
        print("=> ce: %s" %(Ce.ALTA))
        self.declare(Land(Ce.ALTA))

    @Rule(Land(Ph.ALCALINO))
    def rule_8(self):
        print("\n\n")
        print("=> Extracto soluble: True")

    @Rule(Land(Ph.LIGERAMENTE_ALCALINO))
    def rule_9(self):
        print("\n\n")
        print("=> Extracto soluble: True")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)), Land(Ph.ALCALINO), Land(Ce.ALTA)))
    def rule_10(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(3) Baja mineralización de MO (Baja actividad microbiológica")
        print("     |-(4) Acumulación de iones alcalinoterreos")

    @Rule(AND(Land(arena=P(lambda arena: arena >= 50.0)), Land(Ph.ALCALINO), Land(Ce.ALTA)))
    def rule_11(self):
        print("\n\n")
        print("     |-(1) Revisar las medicionesrealizadas")

    @Rule(AND(Land(limo=P(lambda limo: limo >= 45.0)), Land(Ph.ALCALINO), Land(Ce.ALTA)))
    def rule_12(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromórfico")
        print("     |-(3) Limitaciones físicas temporales")
        print("     |-(4) Baja difusión de Oxígeno y flujo de gases")

    @Rule(AND(Land(limo=P(lambda limo: limo <= 40.0)), Land(arcilla=P(lambda arcilla: arcilla <= 40.0)), Land(Ph.ALCALINO), Land(Ce.ALTA)))
    def rule_13(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fósforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)), Land(Ph.ALCALINO), Land(Ce.BAJA)))
    def rule_14(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(3) Baja mineralización de MO (Baja actvidad microbiológica")
        print("     |-(4) Acumulación de iones alcalinotérreos")
        print("     |-(5) Baja disponibilidad de elementos menores")

    @Rule(AND(Land(arena=P(lambda arena: arena >= 50.0)), Land(Ph.ALCALINO), Land(Ce.BAJA)))
    def rule_15(self):
        print("\n\n")
        print("     |-(1) Revisar las medicionesrealizadas")

    @Rule(AND(Land(limo=P(lambda limo: limo >= 45.0)), Land(Ph.ALCALINO), Land(Ce.BAJA)))
    def rule_16(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromórfico")
        print("     |-(3) Limitaciones físicas temporales")
        print("     |-(4) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores")

    @Rule(AND(Land(limo=P(lambda limo: limo <= 40.0)), Land(arena=P(lambda arena: arena <= 40.0)), Land(Ph.ALCALINO), Land(Ce.ALTA)))
    def rule_17(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fósforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.ALTA)))
    def rule_18(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(3) Baja mineralización de MO (Baja actvidad microbiológica")
        print("     |-(4) Acumulación de iones alcalinotérreos")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")
        print("     |-(7) Baja disponibilidad de Fósforo (Precipitación)")

    @Rule(AND(Land(arena=P(lambda arena: arena >= 50.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.ALTA)))
    def rule_19(self):
        print("\n\n")
        print("     |-(1) Revisar las medicionesrealizadas")

    @Rule(AND(Land(limo=P(lambda limo: limo >= 45.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.ALTA)))
    def rule_20(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromórfico")
        print("     |-(3) Limitaciones físicas temporales")
        print("     |-(4) Baja difusión de Oxígeno y flujo de gases")

    @Rule(AND(Land(limo=P(lambda limo: limo <= 40.0)), Land(arena=P(lambda arena: arena <= 40.0)), Land(arcilla=P(lambda arcilla: arcilla <= 40.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.ALTA)))
    def rule_21(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fósforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.BAJA)))
    def rule_22(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(3) Baja mineralización de MO (Baja actvidad microbiológica")
        print("     |-(4) Acumulación de iones alcalinotérreos")
        print("     |-(5) Baja disponibilidad de elementos menores")

    @Rule(AND(Land(arena=P(lambda arena: arena >= 50.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.BAJA)))
    def rule_23(self):
        print("\n\n")
        print("     |-(1) Revisar las medicionesrealizadas")

    @Rule(AND(Land(limo=P(lambda limo: limo >= 45.0)), Land(Ph.LIGERAMENTE_ALCALINO), Land(Ce.BAJA)))
    def rule_24(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusión de Oxígeno y flujo de gases")
        print("     |-(3) Baja mineralización de MO (Baja actvidad microbiológica")
        print("     |-(4) Acumulación de iones alcalinotérreos")
        print("     |-(5) Baja disponibilidad de elementos menores")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)),
    Land(Ph.NEUTRO),
    Land(Ce.ALTA)))
    def rule__25(self):
        print("\n\n")
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica)	")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Salinidad en el suelo")

    @Rule (Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.NEUTRO), 
    Land(Ce.ALTA))
    def rule_26(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.NEUTRO),
    Land(Ce.ALTA))
    def rule_27(self):
        print("\n\n")
        print("     |-(1) Salinidad en el suelo")

    @Rule(AND(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.NEUTRO), 
    Land(Ce.ALTA)))
    def rule_28(self):
        print("\n\n")
        print("CalcularIntercambiables")

    @Rule(AND(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)), 
    Land(Ph.NEUTRO), 
    Land(Ce.BAJA)))
    def rule_29(self):
        print("\n\n")
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica)	")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Limitaciones de movimiento de agua")

    @Rule(Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.NEUTRO),
    Land(Ce.BAJA))
    def rule_30(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.NEUTRO),
    Land(Ce.BAJA))
    def rule_31(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")

    @Rule(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.NEUTRO),
    Land(Ce.BAJA))
    def rule_32(self):
        print("\n\n")
        print("CalcularIntercambiables")

    @Rule(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.BAJA))
    def rule_33(self):
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")
        print("     |-(7) Baja disponibilidad de Fosforo (Precipitación)")

    @Rule(Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.ALTA))
    def rule_34(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.ALTA))
    def rule_35(self):
        print("\n\n")
        print("     |-(1) Contenido de Aluminio")
        print("     |-(2) Sulfatos altos")
        print("     |-(3) Impedancia")

    @Rule(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.ALTA))
    def rule_36(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.BAJA))
    def rule_37(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.BAJA))
    def rule_38(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.BAJA))
    def rule_39(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.LIGERAMENTE_ACIDO),
    Land(Ce.ALTA))
    def rule_40(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")  
        print("     |-(3) Baja disponibilidad de elementos menores ")

    @Rule(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)),
    Land(Ph.ACIDO),
    Land(Ce.ALTA))
    def rule_41(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Acumulacion de iones alcalinoterreos	")
        print("     |-(4) Salinidad en el suelo")
        print("     |-(5) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(6) Baja disponibilidad de Calcio")
        print("     |-(7) Contenido de Aluminio")


    @Rule(Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.ACIDO),
    Land(Ce.ALTA))
    def rule_42(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.ACIDO),
    Land(Ce.ALTA))
    def rule_43(self):
        print("\n\n")
        print("     |-(1) Contenido de Aluminio")
        print("     |-(2) Sulfatos altos")
        print("     |-(3) Impedancia")

    @Rule(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.ACIDO),
    Land(Ce.ALTA))
    def rule_44(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(Land(arcilla=P(lambda arcilla: arcilla >= 40.0)),
    Land(Ph.ACIDO),
    Land(Ce.BAJA))
    def rule_45(self):
        print("\n\n")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(Land(arena=P(lambda arena: arena >= 50.0)),
    Land(Ph.ACIDO),
    Land(Ce.BAJA))
    def rule_46(self):
        print("\n\n")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(Land(limo=P(lambda limo: limo >= 45.0)),
    Land(Ph.ACIDO),
    Land(Ce.BAJA))
    def rule_47(self):
        print("\n\n")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(Land(limo=P(lambda limo: limo <= 40.0)),
    Land(arena=P(lambda arena: arena <= 40.0)),
    Land(arcilla=P(lambda arcilla: arcilla <= 40.0)),
    Land(Ph.ACIDO),
    Land(Ce.BAJA))
    def rule_48(self):
        print("\n\n")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")

# %% [markdown]
# ### Compile

# %%
engine = LandRules()
engine.reset()
engine.declare(Land(ph=4.7, ce=0.8,PH=Ph.LIGERAMENTE_ACIDO,arcilla=50,CE=Ce.ALTA,arena=51,limo=40))
engine.run()
# Out:
# => ph: ACIDO
#
#
#
# => ce: ALTA
#
#
#
#      |-(1) Limitaciones de movimiento de agua
#      |-(2) Baja difusion de Oxigeno y flujo de gases
#      |-(3) Acumulacion de iones alcalinoterreos
#      |-(4) Salinidad en el suelo
#      |-(5) Baja disponibilidad de Fosforo (Precipitación)
#      |-(6) Baja disponibilidad de Calcio
#      |-(7) Contenido de Aluminio
#
#
#
#      |-(1) Revisar las mediciones realizadas.
