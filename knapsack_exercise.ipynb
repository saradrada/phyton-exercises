# %% [markdown]
# # Knapsack problem
#
# Given a list of items and a bag maximum capacity, find the best combination of items.
#
# The algorithm to complete:

# %%
import random
import math

class KnapsackGenetic:
  def __init__(self, params):
    self.ALL_NUMBERS = list(range(params["max_per_item"] + 1))
    self.params = params
    self.specimen = [None] * self.params["generation_size"]

    self.create_initial_population()

  def create_initial_population(self):
    self.specimen = list(map(
        lambda _: list(map(
            lambda _: random.choice(self.ALL_NUMBERS),
            [None] * len(self.params["items"])
        )),
        self.specimen
    ))

  def fitness(self, specimen):
    elementos =  list(zip(self.params["items"],specimen))
    return sum(map(lambda x: x[1]*x[0].value, elementos)) if (sum(map(lambda x: x[1]*x[0].weight, elementos))) <= params["max_weight"] else 0

  def is_converged(self):
    if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
      return True

    return False

  def get_fit(self):
    evaluations = self.fitness_all()

    max_evaluation = max(evaluations)

    max_index = evaluations.index(max_evaluation)

    return self.specimen[max_index], max_evaluation

  def fitness_all(self):
    return list(map(self.fitness, self.specimen))

  def select_specimen(self, specimen_evaluations):
    specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))

    specimen_and_evaluations.sort(key=lambda e: e[1], reverse = True)

    n_top = int(math.ceil(len(self.specimen) * params["select_top"]))

    return list(map(lambda s: s[0], specimen_and_evaluations[:n_top]))
  
  def mutate(self, specimen):
    n_digits = int((len(specimen))*params["mutation_percentage"]) 
    digit_indexes = random.sample(list(range(len(specimen))), n_digits)
    mutated = specimen[:]

    for idx in digit_indexes:
        mutated[idx] = random.choice(self.ALL_NUMBERS)

    return mutated

  def generate_children(self, selected_specimen):  
    mutated_specimen = [None] * len(self.specimen)

    for i in range(len(mutated_specimen)):
      mutated_specimen[i] = self.mutate(random.choice(selected_specimen))

    return mutated_specimen

  def run(self):
    generation_number = 1

    while generation_number <= self.params["max_generations"] and not self.is_converged():
      top_generation = self.get_fit()
      top_str = "".join(str(top_generation[0]))
      
      print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")

      specimen_evaluations = self.fitness_all()
      selected_specimen = self.select_specimen(specimen_evaluations)
      
      self.specimen = self.generate_children(selected_specimen)
      
      generation_number += 1
    
    return self.get_fit()

# %% [markdown]
# To run the algorithm:

# %%
class Item:
  def __init__(self, value, weight):
    self.value = value
    self.weight = weight

params = {
    "mutation_percentage": 0.4,
    "select_top": 0.05,
    "generation_size": 250,
    "fit_threshold": 50,
    "max_generations": 100,
    "max_weight": 15,
    "max_per_item": 5,
    "items": [Item(4, 12), Item(2, 2), Item(2, 1), Item(1, 1), Item(10,4)]
}

knapsack = KnapsackGenetic(params)
knapsack.run()
# Out:
# Generation #1:	[0, 0, 0, 2, 3]	32
# Generation #2:	[0, 0, 3, 0, 3]	36
# Generation #3:	[0, 0, 2, 1, 3]	35
# Generation #4:	[0, 0, 3, 0, 3]	36
# Generation #5:	[0, 0, 3, 0, 3]	36
# Generation #6:	[0, 0, 3, 0, 3]	36
# Generation #7:	[0, 0, 2, 1, 3]	35
# Generation #8:	[0, 0, 2, 1, 3]	35
# Generation #9:	[0, 0, 3, 0, 3]	36
# Generation #10:	[0, 0, 3, 0, 3]	36
# Generation #11:	[0, 0, 3, 0, 3]	36
# Generation #12:	[0, 0, 3, 0, 3]	36
# Generation #13:	[0, 0, 3, 0, 3]	36
# Generation #14:	[0, 0, 3, 0, 3]	36
# Generation #15:	[0, 0, 2, 1, 3]	35
# Generation #16:	[0, 0, 2, 1, 3]	35
# Generation #17:	[0, 0, 2, 1, 3]	35
# Generation #18:	[0, 0, 3, 0, 3]	36
# Generation #19:	[0, 0, 3, 0, 3]	36
# Generation #20:	[0, 0, 3, 0, 3]	36
# Generation #21:	[0, 0, 2, 1, 3]	35
# Generation #22:	[0, 0, 3, 0, 3]	36
# Generation #23:	[0, 0, 3, 0, 3]	36
# Generation #24:	[0, 0, 3, 0, 3]	36
# Generation #25:	[0, 0, 3, 0, 3]	36
# Generation #26:	[0, 0, 3, 0, 3]	36
# Generation #27:	[0, 0, 3, 0, 3]	36
# Generation #28:	[0, 0, 3, 0, 3]	36
# Generation #29:	[0, 0, 3, 0, 3]	36
# Generation #30:	[0, 0, 3, 0, 3]	36
# Generation #31:	[0, 0, 3, 0, 3]	36
# Generation #32:	[0, 0, 3, 0, 3]	36
# Generation #33:	[0, 0, 3, 0, 3]	36
# Generation #34:	[0, 0, 3, 0, 3]	36
# Generation #35:	[0, 0, 3, 0, 3]	36
# Generation #36:	[0, 0, 3, 0, 3]	36
# Generation #37:	[0, 0, 3, 0, 3]	36
# Generation #38:	[0, 0, 2, 1, 3]	35
# Generation #39:	[0, 0, 3, 0, 3]	36
# Generation #40:	[0, 0, 3, 0, 3]	36
# Generation #41:	[0, 0, 3, 0, 3]	36
# Generation #42:	[0, 0, 3, 0, 3]	36
# Generation #43:	[0, 0, 3, 0, 3]	36
# Generation #44:	[0, 0, 3, 0, 3]	36
# Generation #45:	[0, 0, 3, 0, 3]	36
# Generation #46:	[0, 0, 3, 0, 3]	36
# Generation #47:	[0, 0, 3, 0, 3]	36
# Generation #48:	[0, 0, 3, 0, 3]	36
# Generation #49:	[0, 0, 3, 0, 3]	36
# Generation #50:	[0, 0, 3, 0, 3]	36
# Generation #51:	[0, 0, 2, 1, 3]	35
# Generation #52:	[0, 0, 3, 0, 3]	36
# Generation #53:	[0, 0, 3, 0, 3]	36
# Generation #54:	[0, 0, 1, 2, 3]	34
# Generation #55:	[0, 0, 3, 0, 3]	36
# Generation #56:	[0, 0, 2, 1, 3]	35
# Generation #57:	[0, 0, 2, 1, 3]	35
# Generation #58:	[0, 0, 3, 0, 3]	36
# Generation #59:	[0, 0, 3, 0, 3]	36
# Generation #60:	[0, 0, 3, 0, 3]	36
# Generation #61:	[0, 0, 3, 0, 3]	36
# Generation #62:	[0, 0, 3, 0, 3]	36
# Generation #63:	[0, 0, 2, 1, 3]	35
# Generation #64:	[0, 0, 2, 1, 3]	35
# Generation #65:	[0, 0, 2, 1, 3]	35
# Generation #66:	[0, 0, 3, 0, 3]	36
# Generation #67:	[0, 0, 3, 0, 3]	36
# Generation #68:	[0, 0, 2, 1, 3]	35
# Generation #69:	[0, 0, 2, 1, 3]	35
# Generation #70:	[0, 0, 2, 1, 3]	35
# Generation #71:	[0, 0, 3, 0, 3]	36
# Generation #72:	[0, 0, 3, 0, 3]	36
# Generation #73:	[0, 0, 3, 0, 3]	36
# Generation #74:	[0, 0, 3, 0, 3]	36
# Generation #75:	[0, 0, 3, 0, 3]	36
# Generation #76:	[0, 0, 3, 0, 3]	36
# Generation #77:	[0, 0, 3, 0, 3]	36
# Generation #78:	[0, 0, 3, 0, 3]	36
# Generation #79:	[0, 0, 3, 0, 3]	36
# Generation #80:	[0, 0, 3, 0, 3]	36
# Generation #81:	[0, 0, 3, 0, 3]	36
# Generation #82:	[0, 0, 3, 0, 3]	36
# Generation #83:	[0, 0, 3, 0, 3]	36
# Generation #84:	[0, 0, 3, 0, 3]	36
# Generation #85:	[0, 0, 2, 1, 3]	35
# Generation #86:	[0, 0, 3, 0, 3]	36
# Generation #87:	[0, 0, 3, 0, 3]	36
# Generation #88:	[0, 0, 3, 0, 3]	36
# Generation #89:	[0, 0, 3, 0, 3]	36
# Generation #90:	[0, 0, 3, 0, 3]	36
# Generation #91:	[0, 0, 3, 0, 3]	36
# Generation #92:	[0, 0, 3, 0, 3]	36
# Generation #93:	[0, 0, 3, 0, 3]	36
# Generation #94:	[0, 0, 3, 0, 3]	36
# Generation #95:	[0, 0, 3, 0, 3]	36
# Generation #96:	[0, 0, 3, 0, 3]	36
# Generation #97:	[0, 0, 3, 0, 3]	36
# Generation #98:	[0, 0, 3, 0, 3]	36
# Generation #99:	[0, 0, 3, 0, 3]	36
# Generation #100:	[0, 0, 3, 0, 3]	36
# ([0, 0, 3, 0, 3], 36)
